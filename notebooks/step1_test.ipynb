# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Numpy:", np.__version__)
print("Pandas:", pd.__version__)

import matplotlib
print("Matplotlib:", matplotlib.__version__)

x = np.linspace(0, 10, 100)
y = np.cos(x)
plt.plot(x, y)
plt.title("Step 1 – Test Notebook")
plt.show()
# Out:
# Numpy: 2.3.2
# Pandas: 2.3.1
# Matplotlib: 3.10.5

# %%
import pandas as pd

data = {
    "Day": [1, 2, 3, 4, 5],
    "Progress": [1, 2, 3, 4, 5]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Day  Progress
# 0    1         1
# 1    2         2
# 2    3         3
# 3    4         4
# 4    5         5
